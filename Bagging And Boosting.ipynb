# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:/Users/Raghu Gowda/Desktop/Skillathon Assignments/Predict Loan for Customers/predict_loan.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
# Data Cleanning

# %%
df1=df.drop(['Loan_ID'], axis='columns')

# %%
df1
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
df1.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df2= df1.dropna()

# %%
df2.isna().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
# clearing Objects in Data Set 
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 12 columns):
# Gender               480 non-null object
# Married              480 non-null object
# Dependents           480 non-null object
# Education            480 non-null object
# Self_Employed        480 non-null object
# ApplicantIncome      480 non-null int64
# CoapplicantIncome    480 non-null float64
# LoanAmount           480 non-null float64
# Loan_Amount_Term     480 non-null float64
# Credit_History       480 non-null float64
# Property_Area        480 non-null object
# Loan_Status          480 non-null object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 48.8+ KB

# %%
# seperating Numerical And Categirical Columns
categorical_columns = df2.loc[:,df2.dtypes == object]
numerical_columns = df2.loc[:,((df2.dtypes =='float64')|(df2.dtypes =='int64'))]

# %%
categorical_columns
# Out:
#      Gender Married Dependents     Education Self_Employed Property_Area  \
# 1      Male     Yes          1      Graduate            No         Rural
# 2      Male     Yes          0      Graduate           Yes         Urban
# 3      Male     Yes          0  Not Graduate            No         Urban
# 4      Male      No          0      Graduate            No         Urban
# 5      Male     Yes          2      Graduate           Yes         Urban
# ..      ...     ...        ...           ...           ...           ...
# 609  Female      No          0      Graduate            No         Rural
# 610    Male     Yes         3+      Graduate            No         Rural
# 611    Male     Yes          1      Graduate            No         Urban
# 612    Male     Yes          2      Graduate            No         Urban
# 613  Female      No          0      Graduate           Yes     Semiurban
#
#     Loan_Status
# 1             N
# 2             Y
# 3             Y
# 4             Y
# ...

# %%
numerical_columns
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# 5               5417             4196.0       267.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...

# %%
#Label Encoding for Categorical type Data
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for x in categorical_columns:
    categorical_columns[x]= le.fit_transform(categorical_columns[x])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
categorical_columns
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Property_Area  \
# 1         1        1           1          0              0              0
# 2         1        1           0          0              1              2
# 3         1        1           0          1              0              2
# 4         1        0           0          0              0              2
# 5         1        1           2          0              1              2
# ..      ...      ...         ...        ...            ...            ...
# 609       0        0           0          0              0              0
# 610       1        1           3          0              0              0
# 611       1        1           1          0              0              2
# 612       1        1           2          0              0              2
# 613       0        0           0          0              1              1
#
#      Loan_Status
# 1              0
# 2              1
# 3              1
# ...

# %%
#Concatination of numerical and categorical data columns
df3= pd.concat([categorical_columns,numerical_columns], axis='columns')

# %%
df3
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Property_Area  \
# 1         1        1           1          0              0              0
# 2         1        1           0          0              1              2
# 3         1        1           0          1              0              2
# 4         1        0           0          0              0              2
# 5         1        1           2          0              1              2
# ..      ...      ...         ...        ...            ...            ...
# 609       0        0           0          0              0              0
# 610       1        1           3          0              0              0
# 611       1        1           1          0              0              2
# 612       1        1           2          0              0              2
# 613       0        0           0          0              1              1
#
#      Loan_Status  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 12 columns):
# Gender               480 non-null int32
# Married              480 non-null int32
# Dependents           480 non-null int32
# Education            480 non-null int32
# Self_Employed        480 non-null int32
# Property_Area        480 non-null int32
# Loan_Status          480 non-null int32
# ApplicantIncome      480 non-null int64
# CoapplicantIncome    480 non-null float64
# LoanAmount           480 non-null float64
# Loan_Amount_Term     480 non-null float64
# Credit_History       480 non-null float64
# dtypes: float64(4), int32(7), int64(1)
# memory usage: 35.6 KB

# %% [markdown]
# # Spliting And Training the model

# %%
# indipendent variable Data frame (X)
X = df3.drop(['Loan_Status'], axis='columns')
# Dependent variable Data frame
y = df3.Loan_Status

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
# training the model
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
model_params = {
    'svm':{'model':SVC(gamma='auto'), 'params':{'kernel':['rbf','linear']} },
    
    'RandomForestClassifier':{'model': RandomForestClassifier(),'params':{'n_estimators':[1,10,20]}},
    
    'LogisticRegression':{'model':LogisticRegression(solver='liblinear',multi_class='auto'),'params':{'C':[1,10,30]}},
        
    'KNeighborsClassifier':{'model': KNeighborsClassifier(),'params': {}},
    
    'Decision_tree':{'model': DecisionTreeClassifier(),'params': {'criterion': ['gini','entropy']}}
    
}

# %%
from sklearn.model_selection import GridSearchCV
scores = []

for model_name, mp in model_params.items():
    clf = GridSearchCV(mp['model'], mp['params'], cv=3)
    clf.fit(X_train,y_train)
    scores.append({'model': model_name,'best_score': clf.best_score_})

# %%
df_scores = pd.DataFrame(scores,columns=['model','best_score'])
df_scores
# Out:
#                     model  best_score
# 0                     svm    0.729167
# 1  RandomForestClassifier    0.763021
# 2      LogisticRegression    0.794271
# 3    KNeighborsClassifier    0.638021
# 4           Decision_tree    0.705729

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import confusion_matrix as cm
from sklearn.ensemble import AdaBoostClassifier

# %%
# Using Bagging and Boosting technique to reduce Bias and Variance 
# Bagging
bag_clf = BaggingClassifier(DecisionTreeClassifier(random_state=29), n_estimators=500,max_samples=100,
                            bootstrap=True, n_jobs=-1, random_state=29)
bag_clf.fit(X_train, y_train)

# Boosting
ada_clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), n_estimators=200,learning_rate=0.5, random_state=50)

ada_clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#                    base_estimator=DecisionTreeClassifier(class_weight=None,
#                                                          criterion='gini',
#                                                          max_depth=1,
#                                                          max_features=None,
#                                                          max_leaf_nodes=None,
#                                                          min_impurity_decrease=0.0,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=2,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          presort=False,
#                                                          random_state=None,
# ...

# %%
bag_clf.score(X_test,y_test)
# Out:
# 0.84375

# %%
ada_clf.score(X_test,y_test)
# Out:
# 0.8333333333333334
